# %%
import sys
# sys.path.append("/Users/bubble/Desktop/Project/Infrasound Sensor/Layout/Code/acousticsensor")
import numpy as np
import gdsfactory as gf

cell_temp = gf.Component()

# %%
# pad and lines
pad = gf.Component()

# lines
line_base = gf.Component()
line_half = gf.Component()
# define the cross section
w1 = 10
w2 = 1  
s1 = gf.Section(width=w1, offset=0, layer=(2, 0), name="1", port_names=("o1", "o2"))
X1 = gf.CrossSection(sections=[s1])
s2 = gf.Section(width=w2, offset=0, layer=(2, 0), name="1", port_names=("o1", "o2"))
X2 = gf.CrossSection(sections=[s2])
# define the path
# define distance
d1 = 200
radius = 20
h1 = 20
d5 = 1.5
p1 = gf.path.straight(length=d1)
p = p1
wg1 = gf.path.extrude(p, X1)
p4 = gf.path.arc(radius=radius, angle=-90)
Xtrans = gf.path.transition(cross_section1=X1, cross_section2=X2, width_type="sine")
curve_transition = gf.path.extrude_transition(p4, Xtrans)

wg1_ref = line_base << wg1
wg2_ref = line_base << curve_transition
wg2_ref.connect("o1", wg1_ref.ports["o2"])

P = gf.Path()
p5 = gf.path.straight(length=h1)
p6 = gf.path.straight(length=d5)
P += p5
P.end_angle += 90  # "Turn" 90 deg (left)
P += p6
wg3 = gf.path.extrude(P, X2)
wg3_ref = line_base << wg3
wg3_ref.connect("o1", wg2_ref.ports["o2"])

# line_base.show()
d = d1+radius+d5
line_base_ref1 = line_half << line_base
line_base_ref2 = line_half << line_base
line_base_ref2.dmirror_x(d)
# add connection
w_con = (d5-w2/2)*2
h_con = 3-w2
connection = gf.components.rectangle(size=(w_con, h_con), layer=(2, 0))
line_half.add_ref(connection).move((-w_con/2+3*d, radius+h1-h_con-w2/2))
pad.add_ref(line_half)
pad.add_ref(line_half).drotate(angle=180, center=(2*d, 0))
# pad.show()
# Out:
# Unnamed_2: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x126c60650>, layer_enclosures=LayerEnclosureModel(root={'5c226817': LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure')}), cross_sections={'5c226817_10000': SymmetricalCrossSection(width=10000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_10000'), '5c226817_1000': SymmetricalCrossSection(width=1000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_1000'), '5c226817_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_2000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x126c60550>, factories={'taper': <function taper at 0x13680ec00>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x1274e0360>, 'bend_circular': <function bend_circular at 0x13680d440>, 'bend_euler': <function bend_euler at 0x13680dee0>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x1334594e0>, 'straight': <function straight at 0x13687bf60>, 'rotate': <function rotate at 0x1361a6660>, 'mirror': <function mirror at 0x1361a67a0>, 'from_image': <function from_image at 0x13639c5e0>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x13678c7c0>, 'bend_circular_heater': <function bend_circular_heater at 0x13680d620>, 'bend_euler_s': <function bend_euler_s at 0x13680dd00>, 'bezier': <function bezier at 0x13680e2a0>, 'bend_s': <function bend_s at 0x13680e480>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x13680e660>, 'ramp': <function ramp at 0x13680ea20>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x13680eca0>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x13680ef20>, 'taper_sc_nc': <function taper_sc_nc at 0x13680f060>, 'taper_nc_sc': <function taper_nc_sc at 0x13680f1a0>, 'taper_adiabatic': <function taper_adiabatic at 0x13680f420>, 'taper_cross_section': <function taper_cross_section at 0x13678d620>, 'taper_from_csv': <function taper_from_csv at 0x13680f4c0>, 'taper_parabolic': <function taper_parabolic at 0x13680f600>, 'add_termination': <function add_termination at 0x13680e5c0>, 'add_trenches': <function add_trenches at 0x13680f2e0>, 'array': <function array at 0x13680f7e0>, 'copy_layers': <function copy_layers at 0x13680fce0>, 'extend_ports_list': <function extend_ports_list at 0x13680fe20>, 'extend_ports': <function extend_ports at 0x136844040>, 'pack_doe': <function pack_doe at 0x136844860>, 'pack_doe_grid': <function pack_doe_grid at 0x1368449a0>, 'splitter_chain': <function splitter_chain at 0x136844ae0>, 'mzi': <function mzi at 0x136844f40>, 'mzi_lattice': <function mzi_lattice at 0x1368451c0>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x136845300>, 'mzi_pads_center': <function mzi_pads_center at 0x1368454e0>, 'mzit': <function mzit at 0x136845620>, 'mzit_lattice': <function mzit_lattice at 0x136845760>, 'splitter_tree': <function splitter_tree at 0x136845120>, 'coupler_symmetric': <function coupler_symmetric at 0x136845800>, 'coupler_straight': <function coupler_straight at 0x136845940>, 'coupler': <function coupler at 0x136845a80>, 'coupler90': <function coupler90 at 0x136845bc0>, 'coupler90bend': <function coupler90bend at 0x136845c60>, 'coupler_adiabatic': <function coupler_adiabatic at 0x136845f80>, 'coupler_asymmetric': <function coupler_asymmetric at 0x136846200>, 'coupler_bent_half': <function coupler_bent_half at 0x136846480>, 'coupler_bent': <function coupler_bent at 0x1368465c0>, 'coupler_broadband': <function coupler_broadband at 0x136846840>, 'coupler_full': <function coupler_full at 0x136846980>, 'coupler_ring': < ...

# %%
# pads
pad_size = 500
h2 = 100
w3 = 20
line_vertical = gf.components.rectangle(size=(w3, h2), layer=(2, 0))
pad.add_ref(line_vertical).move((2*d-w3/2, -h2-w1/2))
sg_pad = gf.components.rectangle(size=(pad_size, pad_size), layer=(2, 0))
pad.add_ref(sg_pad).move((-pad_size, w1/2-pad_size))
pad.add_ref(sg_pad).move((4*d, w1/2-pad_size))
pad.add_ref(sg_pad).move((2*d-pad_size/2, -w1/2-pad_size-h2))

# pad.show()
# Out:
# Unnamed_2: ports ['e1', 'e2', 'e3', 'e4'], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x126c60650>, layer_enclosures=LayerEnclosureModel(root={'5c226817': LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure')}), cross_sections={'5c226817_10000': SymmetricalCrossSection(width=10000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_10000'), '5c226817_1000': SymmetricalCrossSection(width=1000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_1000'), '5c226817_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_2000'), '5c226817_100000': SymmetricalCrossSection(width=100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_100000'), '5c226817_20000': SymmetricalCrossSection(width=20000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_20000'), '5c226817_500000': SymmetricalCrossSection(width=500000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_500000')}, enclosure=KCellEnclosure(enclosures=LayerEnclosureCollection(enclosures=[])), library=<klayout.dbcore.Library object at 0x126c60550>, factories={'taper': <function taper at 0x13680ec00>, 'bend_s_bezier': <function bend_s_bezier_factory.<locals>.bend_s_bezier at 0x1274e0360>, 'bend_circular': <function bend_circular at 0x13680d440>, 'bend_euler': <function bend_euler at 0x13680dee0>, 'bend_s_euler': <function bend_s_euler_factory.<locals>.bend_s_euler at 0x1334594e0>, 'straight': <function straight at 0x13687bf60>, 'rotate': <function rotate at 0x1361a6660>, 'mirror': <function mirror at 0x1361a67a0>, 'from_image': <function from_image at 0x13639c5e0>, 'floorplan_with_block_letters': <function floorplan_with_block_letters at 0x13678c7c0>, 'bend_circular_heater': <function bend_circular_heater at 0x13680d620>, 'bend_euler_s': <function bend_euler_s at 0x13680dd00>, 'bezier': <function bezier at 0x13680e2a0>, 'bend_s': <function bend_s at 0x13680e480>, 'add_fiber_array_optical_south_electrical_north': <function add_fiber_array_optical_south_electrical_north at 0x13680e660>, 'ramp': <function ramp at 0x13680ea20>, 'taper_strip_to_ridge': <function taper_strip_to_ridge at 0x13680eca0>, 'taper_strip_to_ridge_trenches': <function taper_strip_to_ridge_trenches at 0x13680ef20>, 'taper_sc_nc': <function taper_sc_nc at 0x13680f060>, 'taper_nc_sc': <function taper_nc_sc at 0x13680f1a0>, 'taper_adiabatic': <function taper_adiabatic at 0x13680f420>, 'taper_cross_section': <function taper_cross_section at 0x13678d620>, 'taper_from_csv': <function taper_from_csv at 0x13680f4c0>, 'taper_parabolic': <function taper_parabolic at 0x13680f600>, 'add_termination': <function add_termination at 0x13680e5c0>, 'add_trenches': <function add_trenches at 0x13680f2e0>, 'array': <function array at 0x13680f7e0>, 'copy_layers': <function copy_layers at 0x13680fce0>, 'extend_ports_list': <function extend_ports_list at 0x13680fe20>, 'extend_ports': <function extend_ports at 0x136844040>, 'pack_doe': <function pack_doe at 0x136844860>, 'pack_doe_grid': <function pack_doe_grid at 0x1368449a0>, 'splitter_chain': <function splitter_chain at 0x136844ae0>, 'mzi': <function mzi at 0x136844f40>, 'mzi_lattice': <function mzi_lattice at 0x1368451c0>, 'mzi_lattice_mmi': <function mzi_lattice_mmi at 0x136845300>, 'mzi_pads_center': <function mzi_pads_center at 0x1368454e0>, 'mzit': <function mzit at 0x136845620>, 'mzit_lattice': <function mzit_lattice at 0x136845760>, 'splitter_tree': <function splitter_tree at 0x136845120>, 'coupler_symmetric': <function coupler_symmetric at 0x136845800>, 'coupler_straight': <function coupler_straight at 0x136845940>, 'c ...

# %%
# cell
L = [250, 500, 750, 1000]
g = 30
column_list = [1, 2, 4, 8, 16]
k = len(L) * len(column_list)
w_total = 80

mesh = [None] * k
for i in range(k):
    mesh[i] = gf.Component()
block = gf.Component()
block_temp = gf.Component()
origin = [0, 0]
count = 0

for i in range(len(L)):
    for j in range(len(column_list)):
        w = w_total / column_list[j]
        # single grid
        column = column_list[j]
        height = L[i] - w
        for m in range(column-1):
            sg = gf.components.rectangle(size=(g, height), layer=(8, 0))
            sf_ref = mesh[count] << sg
            sf_ref.move((origin[0]+m*(g+w), 0))    # hole between the beams
        fra_width = (column-1) * (g + w) + w
        beam_frame = gf.components.rectangle(size=(fra_width, L[i]), layer=(9, 0))
        beam_ref = mesh[count] << beam_frame
        beam_ref.movex(origin[0]-w)
        
        # length mark
        T = gf.components.text(f"{count}-L={L[i]}, n={column_list[j]}", size=50, layer=(1, 0))
        T_ref = block << T
        # add pad
        pad_ref = block << pad
        # add backside frame/etch
        size = 1000
        back_temp = gf.Component()
        frame = gf.components.rectangle(size=(size, 1250), layer=(4, 0))
        backside = gf.components.rectangle(size=(size+371.72, 1250+371.72), layer=(3, 0))
        back_temp << frame
        back_temp.add_ref(backside).movex(-371.72/2).movey(-371.72/2)
        mesh[count].add_ref(back_temp).movex((-size+fra_width)/2-w)        
        mesh_ref = block_temp << mesh[count]
        if j == 0:
            mesh_ref.movex(w/2)
        else:
            mesh_ref.movex(w/2-((column_list[j]//2)-1)*(w+g))
        # adjust position
        spacing_x = 2800
        spacing_y = 2600
        mesh_ref.movey(spacing_y*i-250).movex(spacing_x*j)
        T_ref.movey(spacing_y*i-250-700).movex(spacing_x*j)
        pad_ref.move((-3*d, spacing_y*i-250-radius)).movex(spacing_x*j)
        count += 1
beam_temp = gf.boolean(A = block_temp, B = block_temp,  operation="not", layer1=(4, 0), layer2=(9, 0), layer=(1, 0))
block << beam_temp
beam_temp = gf.boolean(A = block_temp, B = block_temp,  operation="or", layer1=(8, 0), layer2=(15, 0), layer=(1, 0))
block << beam_temp
beam_temp = gf.boolean(A = block_temp, B = block_temp,  operation="or", layer1=(3, 0), layer2=(15, 0), layer=(3, 0))
block << beam_temp
# block.show()

# %%
# boolean operation
cell_temp.add_ref(block).move((2000, 1500))
# frame
frame1 = gf.components.rectangle(size=(15000, 10830), layer=(20, 0))
cell_temp << frame1
frame2 = gf.components.rectangle(size=(20000, 15830), layer=(21, 0))
frame2_ref = cell_temp << frame2
frame2_ref.move((-2500, -2500))

cell_mesh_resistive = gf.Component()
cell_ref = cell_mesh_resistive << cell_temp
cell_ref.move((2500, -7500))
# cell_mesh_resistive.show()
# cell_mesh_resistive.write_gds("mesh.gds")
# cell_mesh_resistive.plot()
# Out:
# Unnamed_179: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x126c60650>, layer_enclosures=LayerEnclosureModel(root={'5c226817': LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), '4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), '9e36fa27': LayerEnclosure(layer_sections={}, main_layer=DEEPTRENCH (4/0), yaml_tag='!Enclosure'), '56396fc8': LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), 'a4b5fcfc': LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), '6b4bcfc2': LayerEnclosure(layer_sections={}, main_layer=N (20/0), yaml_tag='!Enclosure'), 'a5f0d270': LayerEnclosure(layer_sections={}, main_layer=P (21/0), yaml_tag='!Enclosure')}), cross_sections={'5c226817_10000': SymmetricalCrossSection(width=10000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_10000'), '5c226817_1000': SymmetricalCrossSection(width=1000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_1000'), '5c226817_2000': SymmetricalCrossSection(width=2000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_2000'), '5c226817_100000': SymmetricalCrossSection(width=100000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_100000'), '5c226817_20000': SymmetricalCrossSection(width=20000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_20000'), '5c226817_500000': SymmetricalCrossSection(width=500000, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB150 (2/0), yaml_tag='!Enclosure'), name='5c226817_500000'), '4fb2b992_250000': SymmetricalCrossSection(width=250000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_250000'), '4fb2b992_80000': SymmetricalCrossSection(width=80000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_80000'), '9e36fa27_1250000': SymmetricalCrossSection(width=1250000, enclosure=LayerEnclosure(layer_sections={}, main_layer=DEEPTRENCH (4/0), yaml_tag='!Enclosure'), name='9e36fa27_1250000'), '9e36fa27_1000000': SymmetricalCrossSection(width=1000000, enclosure=LayerEnclosure(layer_sections={}, main_layer=DEEPTRENCH (4/0), yaml_tag='!Enclosure'), name='9e36fa27_1000000'), '56396fc8_1621720': SymmetricalCrossSection(width=1621720, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_1621720'), '56396fc8_1371720': SymmetricalCrossSection(width=1371720, enclosure=LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure'), name='56396fc8_1371720'), 'a4b5fcfc_210000': SymmetricalCrossSection(width=210000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_210000'), 'a4b5fcfc_30000': SymmetricalCrossSection(width=30000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_30000'), '4fb2b992_110000': SymmetricalCrossSection(width=110000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_110000'), 'a4b5fcfc_230000': SymmetricalCrossSection(width=230000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_230000'), '4fb2b992_170000': SymmetricalCrossSection(width=170000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_170000'), 'a4b5fcfc_240000': SymmetricalCrossSection(width=240000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_240000'), '4fb2b992_290000': SymmetricalCrossSection(width=290000, enclosure=LayerEnclosure(layer ...
