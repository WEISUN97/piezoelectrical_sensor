# %%
import sys
sys.path.append("/Users/bubble/Desktop/Project/Infrasound Sensor/Layout/Code/acousticsensor")

import gdsfactory as gf
import Tools.geo_trans as gt
# TODO
# 1. Change one side of the cell to be comparation with the width
# 2. Different with the width and same width with gap

cell = gf.Component()

# %%
# structure for each side
L = [250, 500, 750, 1000]
g = [10, 20, 30]
w = 2
t = 0.5
beamNum = []
k = (len(L) * len(g))
mesh = [None] * k
for i in range(k):
    mesh[i] = gf.Component()
side = gf.Component()
count = 0
origin = (15000 / 13, 0)
for i in range(4):
    for j in range(3):
        # single grid
        row =   L[i] // (g[j]+w)
        column = row if row % 2 == 0 else row + 1
        beamNum.append((row+1)+ column)
        height = L[i] / row - w
        sg = gf.components.rectangle(size=(g[j], height), layer=(8, 0))
        for m in range(column):
            for n in range(row):
                sf_ref = mesh[count] << sg
                sf_ref.move((origin[0]+m*(g[j]+w), origin[1]+n*(height+w)))
        # frame
        fra_width = column * (g[j] + w) + w
        frame = gf.components.rectangle(size=(fra_width, L[i]), layer=(9, 0))
        frame_ref = mesh[count] << frame
        frame_ref.movex(origin[0]-w)
        # crystal
        mid = origin[0] - w + fra_width / 2
        cry_size = 32
        # cry_height = height+0.1 if j != 0 else 2*height+w+0.1
        crystal = gf.components.rectangle(size=(cry_size, cry_size), layer=(10, 0))
        crystal_ref = mesh[count] << crystal
        crystal_ref.move((mid-cry_size/2, L[i]-cry_size+0.1))
        # holes on crystal
        hole_size = 0.8
        hole_int = 0.9
        hole_dis = hole_int - hole_size
        hole_n = int(cry_size // hole_int)
        margin = 5 // hole_int 
        hole_n = int(hole_n - margin*2) if hole_n % 2 == 0 else int(hole_n - 1 - margin*2)
        hole = gf.components.circle(radius=hole_size/2, layer=(11, 0))
        a = hole_n * hole_size + (hole_n-1) * hole_dis
        a = (cry_size - a) / 2 + hole_size / 2
        for m in range(hole_n):
            for n in range(hole_n):
                hole_ref = mesh[count] << hole
                hole_ref.move((mid-cry_size/2+a, L[i]-cry_size+0.1+a))
                hole_ref.move((m*hole_int, n*hole_int))
        # add mesh[count] to side and adjust position
        mesh_ref = side << mesh[count]
        mesh_ref.movex(count * 15000 / 13)        
        count += 1
# add some beams
for i in range(8):
    beam = gf.components.rectangle(size=(w, L[i//2]), layer=(9, 0))
    beam_ref = side << beam
    beam_ref.movex((i+1.5) * 15000 / 13+L[i//3]//2)


# side.show()
print(beamNum)
# Out:
# [41, 24, 16, 84, 45, 32, 125, 69, 48, 168, 92, 64]

# %%
# left side
mesh = [None] * k
for i in range(k):
    mesh[i] = gf.Component()
side_left = gf.Component()
count = 0
origin = (15000 / 13, 0)
hole_size_list = [0.8, 0.6, 0.4, 0.8, 0.6, 0.4, 0.8, 0.6, 0.4, 0.8, 0.6, 0.4]
hole_int_list = [0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9]
for i in range(4):
    for j in range(3):
        # single grid
        row =   L[i] // (g[j]+w)
        column = row if row % 2 == 0 else row + 1
        beamNum.append((row+1)+ column)
        height = L[i] / row - w
        sg = gf.components.rectangle(size=(g[j], height), layer=(8, 0))
        for m in range(column):
            for n in range(row):
                sf_ref = mesh[count] << sg
                sf_ref.move((origin[0]+m*(g[j]+w), origin[1]+n*(height+w)))
        # frame
        fra_width = column * (g[j] + w) + w
        frame = gf.components.rectangle(size=(fra_width, L[i]), layer=(9, 0))
        frame_ref = mesh[count] << frame
        frame_ref.movex(origin[0]-w)
        # crystal
        mid = origin[0] - w + fra_width / 2
        cry_size = 32
        # cry_height = height+0.1 if j != 0 else 2*height+w+0.1
        crystal = gf.components.rectangle(size=(cry_size, cry_size), layer=(10, 0))
        crystal_ref = mesh[count] << crystal
        crystal_ref.move((mid-cry_size/2, L[i]-cry_size-w+0.1))
        # holes on crystal
        hole_size = hole_size_list[count]
        hole_int = hole_int_list[count]
        hole_dis = hole_int - hole_size
        hole_n = int(cry_size // hole_int)
        margin = 5 // hole_int 
        hole_n = int(hole_n - margin*2) if hole_n % 2 == 0 else int(hole_n - 1 - margin*2)
        hole = gf.components.circle(radius=hole_size/2, layer=(11, 0))
        a = hole_n * hole_size + (hole_n-1) * hole_dis
        a = (cry_size - a) / 2 + hole_size / 2
        for m in range(hole_n):
            for n in range(hole_n):
                hole_ref = mesh[count] << hole
                hole_ref.move((mid-cry_size/2+a, L[i]-cry_size-w+0.1+a))
                hole_ref.move((m*hole_int, n*hole_int))
        # add mesh[count] to side and adjust position
        mesh_ref = side_left << mesh[count]
        mesh_ref.movex(count * 15000 / 13)        
        count += 1
# add some beams
for i in range(8):
    beam = gf.components.rectangle(size=(w, L[i//2]), layer=(9, 0))
    beam_ref = side_left << beam
    beam_ref.movex((i+1.5) * 15000 / 13+L[i//3]//2)

# %%
# right side
mesh = [None] * k
for i in range(k):
    mesh[i] = gf.Component()
side_right = gf.Component()
count = 0
origin = (15000 / 13, 0)
hole_size_list = [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8]
hole_int_list = [0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9]
L = [250, 500, 1000]
g = [30, 30, 30, 30]
column_list = [1, 2, 5, 10]
w_total = 32
for i in range(len(L)):
    for j in range(len(column_list)):
        w = w_total / column_list[j]
        # single grid
        column = column_list[j]
        height = L[i] - w
        sg = gf.components.rectangle(size=(g[j], height), layer=(8, 0))
        for m in range(column-1):
            sf_ref = mesh[count] << sg
            sf_ref.move((origin[0]+m*(g[j]+w), 0))
        # frame
        fra_width = (column-1) * (g[j] + w) + w
        frame = gf.components.rectangle(size=(fra_width, L[i]), layer=(9, 0))
        frame_ref = mesh[count] << frame
        frame_ref.movex(origin[0]-w)
        # crystal
        mid = origin[0] - w + fra_width / 2
        cry_size = 32
        # cry_height = height+0.1 if j != 0 else 2*height+w+0.1
        crystal = gf.components.rectangle(size=(cry_size, cry_size), layer=(10, 0))
        crystal_ref = mesh[count] << crystal
        crystal_ref.move((mid-cry_size/2, L[i]-cry_size+0.1))
        # holes on crystal
        hole_size = hole_size_list[count]
        hole_int = hole_int_list[count]
        hole_dis = hole_int - hole_size
        hole_n = int(cry_size // hole_int)
        margin = 5 // hole_int 
        hole_n = int(hole_n - margin*2) if hole_n % 2 == 0 else int(hole_n - 1 - margin*2)
        hole = gf.components.circle(radius=hole_size/2, layer=(11, 0))
        a = hole_n * hole_size + (hole_n-1) * hole_dis
        a = (cry_size - a) / 2 + hole_size / 2
        for m in range(hole_n):
            for n in range(hole_n):
                hole_ref = mesh[count] << hole
                hole_ref.move((mid-cry_size/2+a, L[i]-cry_size+0.1+a))
                hole_ref.move((m*hole_int, n*hole_int))
        # add mesh[count] to side and adjust position
        mesh_ref = side_right << mesh[count]
        mesh_ref.movex(count * 15000 / 13)        
        count += 1
# add some beams
# for i in range(8):
#     beam = gf.components.rectangle(size=(w, L[i//2]), layer=(9, 0))
#     beam_ref = side_right << beam
#     beam_ref.movex((i+1.5) * 15000 / 13+L[i//3]//2)

# side_right.show()

# %%
# backside etching 15mm * 15mm
backside = gf.components.rectangle(size=(15000, 15000), layer=(3, 0))
# cell << backside
# cell.show()

# %%
# structure for each die
# structure for 4 sides
fside = gf.Component()

double_side = gf.Component()
# structure for double sides
side_ref = double_side << side
side_ref.dmirror_y(15000/2).dmirror_x(15000/2)
double_side << side
# dside_ref = fside << double_side
# dside_ref.drotate(angle=90, center=(15000/2, 15000/2))
fside << double_side

# left side
side_left_ref = fside << side_left
side_left_ref.drotate(angle=-90, center=(15000/2, 15000/2))

# right side
side_right_ref = fside << side_right
side_right_ref.drotate(angle=90, center=(15000/2, 15000/2))

# right side
# fside.show()
# Out:
# Unnamed_243: ports [], vinsts=[] info=Info() kcl=KCLayout(name='DEFAULT', layout=<klayout.dbcore.Layout object at 0x10dcb0ed0>, layer_enclosures=LayerEnclosureModel(root={'a4b5fcfc': LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), '4fb2b992': LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), 'c1ad96cb': LayerEnclosure(layer_sections={}, main_layer=10/0, yaml_tag='!Enclosure'), '56396fc8': LayerEnclosure(layer_sections={}, main_layer=SLAB90 (3/0), yaml_tag='!Enclosure')}), cross_sections={'a4b5fcfc_10500': SymmetricalCrossSection(width=10500, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_10500'), 'a4b5fcfc_10000': SymmetricalCrossSection(width=10000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_10000'), '4fb2b992_250000': SymmetricalCrossSection(width=250000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_250000'), '4fb2b992_242000': SymmetricalCrossSection(width=242000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_242000'), 'c1ad96cb_32000': SymmetricalCrossSection(width=32000, enclosure=LayerEnclosure(layer_sections={}, main_layer=10/0, yaml_tag='!Enclosure'), name='c1ad96cb_32000'), 'a4b5fcfc_20728': SymmetricalCrossSection(width=20728, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_20728'), 'a4b5fcfc_20000': SymmetricalCrossSection(width=20000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_20000'), '4fb2b992_266000': SymmetricalCrossSection(width=266000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_266000'), 'a4b5fcfc_33714': SymmetricalCrossSection(width=33714, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_33714'), 'a4b5fcfc_30000': SymmetricalCrossSection(width=30000, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_30000'), '4fb2b992_258000': SymmetricalCrossSection(width=258000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_258000'), 'a4b5fcfc_10196': SymmetricalCrossSection(width=10196, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_10196'), '4fb2b992_500000': SymmetricalCrossSection(width=500000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_500000'), '4fb2b992_506000': SymmetricalCrossSection(width=506000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_506000'), '4fb2b992_486000': SymmetricalCrossSection(width=486000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_486000'), 'a4b5fcfc_31334': SymmetricalCrossSection(width=31334, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_31334'), '4fb2b992_514000': SymmetricalCrossSection(width=514000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_514000'), 'a4b5fcfc_10096': SymmetricalCrossSection(width=10096, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_10096'), '4fb2b992_750000': SymmetricalCrossSection(width=750000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_750000'), '4fb2b992_746000': SymmetricalCrossSection(width=746000, enclosure=LayerEnclosure(layer_sections={}, main_layer=9/0, yaml_tag='!Enclosure'), name='4fb2b992_746000'), 'a4b5fcfc_20058': SymmetricalCrossSection(width=20058, enclosure=LayerEnclosure(layer_sections={}, main_layer=8/0, yaml_tag='!Enclosure'), name='a4b5fcfc_20058'), 'a4 ...

# %%
# boolean operation
# do backside etching - frame
outside = gf.boolean(A = backside, B = fside,  operation="not", layer1=(3, 0), layer2=(9, 0), layer=(2, 0))
outside = gf.boolean(A = outside, B = fside,  operation="not", layer1=(2, 0), layer2=(10, 0), layer=(1, 0))
cell << outside

#  do holes etching - crystal
holes = gf.boolean(A = fside, B = fside,  operation="not", layer1=(8, 0), layer2=(10, 0), layer=(1, 0))
cell << holes
# add holes to cell
pc = gf.boolean(A = fside, B = fside,  operation="not", layer1=(11, 0), layer2=(30, 0), layer=(2, 0))
cell << pc
cell << backside
cell.show()
# cell.write_gds("mesh.gds")
# cell.plot()
